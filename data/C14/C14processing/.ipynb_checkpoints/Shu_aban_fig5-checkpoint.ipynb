# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import C14preproc as prep
import pylab
import C14utils
import matplotlib
import socplot_lib as socplt
import isamcalc_lib as isam
import SOCtools as soc

# %%
# =====================================================================
#  Plot the simulated 1-m integrated D14C profiles for Umakant's samples
#  Compare with the others?
# =====================================================================
# ================================
## Get the calculated tau
# ================================
tau=np.loadtxt("isam_um_tau.csv")
ttt_con = [27.471011,  14.825332,  40.397568,  40.110268,  23.388271]
ttt_bio = [23.217821,  11.539868,  40.759487,  38.883131,  19.468271]
ttt_cryo = [20.367977,  14.818091,  40.762897,  41.430041,  23.254243]
ttt_dep = [12.016449,  11.721462,  24.01346 ,  19.141968,  18.565731]
ttt_moss = [26.451637,  15.396229,  36.293863,  35.21914 ,  18.20631]
ttt_soc = [27.471011,  14.825403,  30.870009,  31.556624,  23.144087]
t_bio = [0,0,0,0,0]
t_cryo = [0,0,0,0,0]
t_dep = [0,0,0,0,0]
t_moss = [0,0,0,0,0]
t_soc = [0,0,0,0,0]

for i in np.arange(0,5):
    t_bio[i] = ttt_con[i] - ttt_bio[i]
    t_cryo[i] = ttt_con[i] - ttt_cryo[i]
    t_dep[i] = ttt_con[i] - ttt_dep[i]
    t_moss[i] = ttt_con[i] - ttt_moss[i]
    t_soc[i] = ttt_con[i] - ttt_soc[i]

data_bplot = [t_bio, t_cryo, t_dep, t_moss, t_soc]

# Plot boxplot for tau
plt.figure(figsize=(16,10))
boxprops = dict(linestyle='-', linewidth=4, color='darkgoldenrod')
flierprops = dict(marker='o', markerfacecolor='green', markersize=18,
                  linestyle='none')
medianprops = dict(linestyle='-.', linewidth=2.5, color='firebrick')
meanprops = dict(marker='^', markerfacecolor='blue', markersize=18,
                  linestyle='none')
plt.boxplot(data_bplot, boxprops=boxprops, flierprops=flierprops, \
           medianprops=medianprops, meanprops=meanprops, showmeans=True) #, meanlineprops=meanlineprops)
plt.xticks([1,2,3,4,5], ['Bioturbation', 'Cryoturbation', 'Depth Modifier', 'Moss Insulation', 'Organic layer'], fontsize=20)
plt.yticks([-5, 0, 5, 10, 15, 20, 25], fontsize=20)
plt.show()
#plt.savefig('socchangeeffect_ISAM.png')

# %%
# =====================================================================
#  Plot the simulated 1-m integrated D14C profiles for Umakant's samples
#  Compare with the others?
# =====================================================================
# ================================
## Get the calculated tau
# ================================
tau=np.loadtxt("isam_um_tau.csv")
ttt_con = [1691, 501, 461, 1316, 196]
ttt_bio = [1311, 346, 1391, 1811, 496]
ttt_cryo = [851, 466, 1391, 2800, 726]
ttt_dep = [246, 366, 676, 1206, 511]
ttt_moss = [1731, 386, 1301, 2550, 476]
ttt_soc = [1691, 466, 1201, 1396, 611]
t_bio = [0,0,0,0,0]
t_cryo = [0,0,0,0,0]
t_dep = [0,0,0,0,0]
t_moss = [0,0,0,0,0]
t_soc = [0,0,0,0,0]

for i in np.arange(0,5):
    t_bio[i] = ttt_con[i] - ttt_bio[i]
    t_cryo[i] = ttt_con[i] - ttt_cryo[i]
    t_dep[i] = ttt_con[i] - ttt_dep[i]
    t_moss[i] = ttt_con[i] - ttt_moss[i]
    t_soc[i] = ttt_con[i] - ttt_soc[i]

data_bplot = [t_bio, t_cryo, t_dep, t_moss, t_soc]

# Plot boxplot for tau
plt.figure(figsize=(16,10))
boxprops = dict(linestyle='-', linewidth=4, color='darkgoldenrod')
flierprops = dict(marker='o', markerfacecolor='green', markersize=18,
                  linestyle='none')
medianprops = dict(linestyle='-.', linewidth=2.5, color='firebrick')
meanprops = dict(marker='^', markerfacecolor='blue', markersize=18,
                  linestyle='none')
plt.boxplot(data_bplot, boxprops=boxprops, flierprops=flierprops, \
           medianprops=medianprops, meanprops=meanprops, showmeans=True) #, meanlineprops=meanlineprops)
plt.xticks([1,2,3,4,5], ['Bioturbation', 'Cryoturbation', 'Depth Modifier', 'Moss Insulation', 'Organic layer'], fontsize=20)
plt.yticks([-1500, -1000, -500, 0, 500, 1000, 1500], fontsize=20)
plt.show()
#plt.savefig('effect_ISAM.png')
