# %%
execfile("ustwt_csv.py")
# Out:
# /data/keeling/a/sshu3/anaconda2/lib/python2.7/site-packages/numpy/ma/core.py:4185: UserWarning: Warning: converting a masked element to nan.
#   warnings.warn("Warning: converting a masked element to nan.")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-36d62319871d> in <module>()
# ----> 1 execfile("ustwt_csv.py")
#
# /data/jain1/c/sshu3/SBGC/results/ustwt_csv.py in <module>()
#     230
#     231
# --> 232 plt.plot(x1,y1,marker='>',color='b',linestyle='--',linewidth=1.5)
#     233 plt.plot(x2,y2,marker='<',color='b',linestyle=':',linewidth=1.5)
#     234 plt.plot(x3,y3,marker='>',color='b',linestyle='--',linewidth=1.5)
#
# /data/keeling/a/sshu3/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3316                       mplDeprecation)
#    3317     try:
# -> 3318         ret = ax.plot(*args, **kwargs)
# ...
